# %% [markdown]
# # Cardiovascular Disease Machine Learning Project

# %% [markdown]
# ## INTRODUCTION

# %% [raw]
#                        The Cardiovascular Disease Machine Learning Project aims to study advanced data analysis and machine learning techniques to predict the risk of cardiovascular diseases.
#                        By analyzing various health metrics such as gender, age, health and other lifestyle factors,
# the project seeks to build predictive models that can identify individuals at high risk. This helps in early detection and prevention, leading to better treatment and healthier lives. The project shows how machine learning can improve heart health care.

# %% [markdown]
# ## Description:

# %% [raw]
#                      In this notebook, we are going to predict whether there will be cardiovascular disease or not by using various features like Depression, Diabetes, BMI, Smoking level, Alcohol Consumption,Exercise, health etc
#
#                      The dataset we are going to use is Cardiovascular Disease Machine Learning dataset from Kaggle which contains about 308854 rows and 19 columns features.
#
#                      The dataset contains the labels which we have to predict and the labels are discrete and binary. So the problem we have is a Supervised Classification type.

# %% [markdown]
# ## Motivation:

# %% [raw]
#               Cardiovascular diseases remain a leading cause of mortality worldwide, making early detection crucial for effective management. This project aims to bridge the gap between medical data and actionable insights, enhancing the precision of diagnoses and treatment plans through advanced machine learning techniques.                                                                 By accurately predicting heart disease risk, we can provide timely interventions, reduce healthcare costs, and ultimately save lives through personalized and proactive healthcare.

# %% [markdown]
# ## Column Description

# %% [raw]
# 1. General_Health:           Indicates if the individual has undergone a general health checkup.
# 2. Exercise:                         Frequency or type of exercise performed by the individual.
# 3. Heart_Disease:                    Indicates if the individual has been diagnosed with heart disease.
# 4. Skin_Cancer:                      Indicates if the individual has been diagnosed with skin cancer.
# 5. Other_Cancer:                     Indicates if the individual has been diagnosed with cancers other than skin cancer.
# 6. Depression:                       Indicates if the individual has been diagnosed with depression.
# 7. Diabetes:                         Indicates if the individual has been diagnosed with diabetes.
# 8. Arthritis:                        Indicates if the individual has been diagnosed with arthritis.
# 9. Sex:                              Gender of the individual (e.g., male, female).
# 10.Age_Category:                     Age group or category the individual falls into (e.g., 18-24, 25-34, etc.).
# 11.Height_(cm):                      Height of the individual in centimeters.
# 12.Weight_(kg):                      Weight of the individual in kilograms.
# 13.BMI:                              Body Mass Index calculated from height and weight.
# 14.Smoking_History:                  Smoking history of the individual (e.g., never smoked, former smoker, current smoker).
# 15.Alcohol_Consumption:              Frequency or amount of alcohol consumed by the individual.
# 16.Fruit_Consumption:                Frequency of fruit consumption by the individual.
# 17.Green_Vegetables_Consumption:     Frequency of green vegetable consumption by the individual.
# 18.FriedPotato_Consumption:          Frequency of fried potato consumption by the individual.
# 19.Checkup:                          Routine of checkup

# %% [markdown]
# # Load libraries

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Dataset

# %%
df =pd.read_csv(r"C:\Users\HP\Documents\ML\CVD pred\cvd_df.csv")
df
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 297760      Very Good     Within the past year      Yes            No
# 297761           Fair  Within the past 5 years      Yes            No
# 297762      Very Good      5 or more years ago      Yes            No
# 297763      Very Good     Within the past year      Yes            No
# 297764      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0               No     No         No       No       Yes  Female        70-74
# 1               No     No         No      Yes        No  Female        70-74
# 2               No     No         No      Yes        No  Female        60-64
# 3               No     No         No      Yes        No    Male        75-79
# 4               No     No        Yes       No       Yes    Male        60-64
# ...            ...    ...        ...      ...       ...     ...          ...
# 297760          No     No         No       No        No    Male        25-29
# 297761          No     No         No      Yes        No    Male        65-69
# 297762          No     No        Yes      Yes        No  Female        30-34
# 297763          No     No         No       No        No    Male        65-69
# 297764          No     No         No       No        No  Female        45-49
#
#         Height_(cm)  Weight_(kg)    BMI Smoking_History Alcohol_Consumption  \
# 0               150        32.66  14.54             Yes                  No
# 1               165        77.11  28.29              No                  No
# 2               163        88.45  33.47              No                 yes
# 3               180        93.44  28.73              No                  No
# 4               183       154.22  46.11              No                  No
# ...             ...          ...    ...             ...                 ...
# 297760          168        81.65  29.05              No                 yes
# 297761          180        69.85  21.48              No                 yes
# 297762          157        61.23  24.69             Yes                 yes
# 297763          183        79.38  23.73              No                 yes
# 297764          160        81.19  31.71              No                 yes
#
#         Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                      30                            16
# 1                      30                             0
# 2                      12                             3
# 3                      30                            30
# 4                      12                            12
# ...                   ...                           ...
# 297760                 30                             8
# 297761                 15                            60
# 297762                 40                             8
# 297763                 30                            12
# 297764                  5                            12
#
#         FriedPotato_Consumption
# 0                            12
# 1                             4
# 2                            16
# 3                             8
# 4                            12
# ...                         ...
# 297760                        0
# 297761                        4
# 297762                        4
# 297763                        0
# 297764                        1
#
# [297765 rows x 19 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Fruit_Consumption  \
# count  297765.000000  297765.000000  297765.000000      297765.000000
# mean      169.777986      82.645011      28.596325          29.868151
# std         9.879620      20.487737       6.442881          24.883745
# min        91.000000      24.950000      12.020000           0.000000
# 25%       163.000000      68.040000      24.210000          12.000000
# 50%       170.000000      80.290000      27.440000          30.000000
# 75%       178.000000      93.440000      31.820000          30.000000
# max       190.000000     200.000000      99.330000         120.000000
#
#        Green_Vegetables_Consumption  FriedPotato_Consumption
# count                 297765.000000            297765.000000
# mean                      15.126482                 6.231102
# std                       14.931004                 8.518028
# min                        0.000000                 0.000000
# 25%                        4.000000                 2.000000
# 50%                       12.000000                 4.000000
# 75%                       20.000000                 8.000000
# max                      128.000000               128.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297765 entries, 0 to 297764
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                297765 non-null  object
#  1   Checkup                       297765 non-null  object
#  2   Exercise                      297765 non-null  object
#  3   Heart_Disease                 297765 non-null  object
#  4   Skin_Cancer                   297765 non-null  object
#  5   Cancer                        297765 non-null  object
#  6   Depression                    297765 non-null  object
#  7   Diabetes                      297765 non-null  object
#  8   Arthritis                     297765 non-null  object
#  9   Sex                           297765 non-null  object
#  10  Age_Category                  297765 non-null  object
#  11  Height_(cm)                   297765 non-null  int64
#  12  Weight_(kg)                   297765 non-null  float64
#  13  BMI                           297765 non-null  float64
#  14  Smoking_History               297765 non-null  object
#  15  Alcohol_Consumption           297765 non-null  object
#  16  Fruit_Consumption             297765 non-null  int64
#  17  Green_Vegetables_Consumption  297765 non-null  int64
#  18  FriedPotato_Consumption       297765 non-null  int64
# dtypes: float64(2), int64(4), object(13)
# memory usage: 43.2+ MB

# %% [markdown]
# ##### Shape of the data set

# %%
df.shape

#checking size (col,lin) of dataset
print("Number of rows: " + str(df.shape[0]))
print("Number of Columns: " + str(df.shape[1]))
# Out:
# Number of rows: 297765
# Number of Columns: 19

# %% [markdown]
# ##### checking how many unique values there are per column

# %%
df.nunique()
# Out:
# General_Health                     5
# Checkup                            5
# Exercise                           2
# Heart_Disease                      2
# Skin_Cancer                        2
# Cancer                             2
# Depression                         2
# Diabetes                           2
# Arthritis                          2
# Sex                                2
# Age_Category                      13
# Height_(cm)                       77
# Weight_(kg)                      460
# BMI                             3344
# Smoking_History                    2
# Alcohol_Consumption                2
# Fruit_Consumption                 77
# Green_Vegetables_Consumption      75
# FriedPotato_Consumption           67
# dtype: int64

# %%
df.isnull().sum()
# Out:
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Cancer                          0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %%
df.boxplot()
plt.title('Boxplot for All Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### BMI

# %%
df.boxplot(column='BMI')
plt.title('Boxplot for BMI')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['BMI'] < lower_bound) | (df['BMI'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 9272

# %%
df.boxplot(column='BMI')
plt.title('Boxplot for BMI')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### height

# %%
df.boxplot(column='Height_(cm)')
plt.title('Boxplot for Height_(cm)')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['Height_(cm)'].quantile(0.25)
Q3 = df['Height_(cm)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Height_(cm)'] < lower_bound) | (df['Height_(cm)'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 299

# %%
df.boxplot(column='Height_(cm)')
plt.title('Boxplot for Column1')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### weight

# %%
df.boxplot(column='Weight_(kg)')
plt.title('Boxplot for Weight_(kg)')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['Weight_(kg)'].quantile(0.25)
Q3 = df['Weight_(kg)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Weight_(kg)'] < lower_bound) | (df['Weight_(kg)'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 5721

# %%
df.boxplot(column='Weight_(kg)')
plt.title('Boxplot for Weight_(kg)')
plt.ylabel('Values')
plt.show()

# %%
df.boxplot()
plt.title('Boxplot for All Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation = 90)
plt.show()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0           Very Good     Within the past year       No           Yes
# 1           Very Good     Within the past year      Yes            No
# 2                Poor     Within the past year      Yes           Yes
# 3                Fair     Within the past year      Yes           Yes
# 4                Good     Within the past year      Yes            No
# ...               ...                      ...      ...           ...
# 282468      Very Good     Within the past year      Yes            No
# 282469           Fair  Within the past 5 years      Yes            No
# 282470      Very Good      5 or more years ago      Yes            No
# 282471      Very Good     Within the past year      Yes            No
# 282472      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0               No     No         No      Yes        No  Female        70-74
# 1               No     No         No      Yes        No  Female        60-64
# 2               No     No         No      Yes        No    Male        75-79
# 3               No     No         No       No       Yes    Male        60-64
# 4               No     No         No       No       Yes  Female        65-69
# ...            ...    ...        ...      ...       ...     ...          ...
# 282468          No     No         No       No        No    Male        25-29
# 282469          No     No         No      Yes        No    Male        65-69
# 282470          No     No        Yes      Yes        No  Female        30-34
# 282471          No     No         No       No        No    Male        65-69
# 282472          No     No         No       No        No  Female        45-49
#
#         Height_(cm)  Weight_(kg)    BMI Smoking_History Alcohol_Consumption  \
# 0               165        77.11  28.29              No                  No
# 1               163        88.45  33.47              No                 yes
# 2               180        93.44  28.73              No                  No
# 3               175        69.85  22.74             Yes                  No
# 4               165       108.86  39.94             Yes                 yes
# ...             ...          ...    ...             ...                 ...
# 282468          168        81.65  29.05              No                 yes
# 282469          180        69.85  21.48              No                 yes
# 282470          157        61.23  24.69             Yes                 yes
# 282471          183        79.38  23.73              No                 yes
# 282472          160        81.19  31.71              No                 yes
#
#         Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                      30                             0
# 1                      12                             3
# 2                      30                            30
# 3                      16                             8
# 4                      30                             8
# ...                   ...                           ...
# 282468                 30                             8
# 282469                 15                            60
# 282470                 40                             8
# 282471                 30                            12
# 282472                  5                            12
#
#         FriedPotato_Consumption
# 0                             4
# 1                            16
# 2                             8
# 3                             0
# 4                             8
# ...                         ...
# 282468                        0
# 282469                        4
# 282470                        4
# 282471                        0
# 282472                        1
#
# [282473 rows x 19 columns]

# %% [markdown]
# ##### Checking null values

# %%
df.isnull().sum()
# Out:
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Cancer                          0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %% [markdown]
# # Drop unnecessary columns

# %%
df.drop('Green_Vegetables_Consumption', axis=1, inplace=True)
df.drop('FriedPotato_Consumption', axis=1, inplace=True)
df.drop('Fruit_Consumption', axis=1, inplace=True)
df.drop('Skin_Cancer', axis=1, inplace=True)
df.drop('BMI', axis=1, inplace=True)
df.drop('Arthritis', axis=1, inplace=True)

# %% [markdown]
# # Separting Numeric and category Data

# %%
df_num=df.select_dtypes(['int','float'])
df_num
# Out:
#         Height_(cm)  Weight_(kg)
# 0               165        77.11
# 1               163        88.45
# 2               180        93.44
# 3               175        69.85
# 4               165       108.86
# ...             ...          ...
# 282468          168        81.65
# 282469          180        69.85
# 282470          157        61.23
# 282471          183        79.38
# 282472          160        81.19
#
# [282473 rows x 2 columns]

# %%
df_object=df.select_dtypes(['object'])
df_object
# Out:
#        General_Health                  Checkup Exercise Heart_Disease Cancer  \
# 0           Very Good     Within the past year       No           Yes     No
# 1           Very Good     Within the past year      Yes            No     No
# 2                Poor     Within the past year      Yes           Yes     No
# 3                Fair     Within the past year      Yes           Yes     No
# 4                Good     Within the past year      Yes            No     No
# ...               ...                      ...      ...           ...    ...
# 282468      Very Good     Within the past year      Yes            No     No
# 282469           Fair  Within the past 5 years      Yes            No     No
# 282470      Very Good      5 or more years ago      Yes            No     No
# 282471      Very Good     Within the past year      Yes            No     No
# 282472      Excellent     Within the past year      Yes            No     No
#
#        Depression Diabetes     Sex Age_Category Smoking_History  \
# 0              No      Yes  Female        70-74              No
# 1              No      Yes  Female        60-64              No
# 2              No      Yes    Male        75-79              No
# 3              No       No    Male        60-64             Yes
# 4              No       No  Female        65-69             Yes
# ...           ...      ...     ...          ...             ...
# 282468         No       No    Male        25-29              No
# 282469         No      Yes    Male        65-69              No
# 282470        Yes      Yes  Female        30-34             Yes
# 282471         No       No    Male        65-69              No
# 282472         No       No  Female        45-49              No
#
#        Alcohol_Consumption
# 0                       No
# 1                      yes
# 2                       No
# 3                       No
# 4                      yes
# ...                    ...
# 282468                 yes
# 282469                 yes
# 282470                 yes
# 282471                 yes
# 282472                 yes
#
# [282473 rows x 11 columns]

# %% [markdown]
# # Using Label Encoder for converting category data into numeric

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df_object:
    df_object[i]=le.fit_transform(df_object[i]) 
#convert the cat to label encoder
df_object
# Out:
#         General_Health  Checkup  Exercise  Heart_Disease  Cancer  Depression  \
# 0                    4        4         0              1       0           0
# 1                    4        4         1              0       0           0
# 2                    3        4         1              1       0           0
# 3                    1        4         1              1       0           0
# 4                    2        4         1              0       0           0
# ...                ...      ...       ...            ...     ...         ...
# 282468               4        4         1              0       0           0
# 282469               1        3         1              0       0           0
# 282470               4        0         1              0       0           1
# 282471               4        4         1              0       0           0
# 282472               0        4         1              0       0           0
#
#         Diabetes  Sex  Age_Category  Smoking_History  Alcohol_Consumption
# 0              1    0            10                0                    0
# 1              1    0             8                0                    1
# 2              1    1            11                0                    0
# 3              0    1             8                1                    0
# 4              0    0             9                1                    1
# ...          ...  ...           ...              ...                  ...
# 282468         0    1             1                0                    1
# 282469         1    1             9                0                    1
# 282470         1    0             2                1                    1
# 282471         0    1             9                0                    1
# 282472         0    0             5                0                    1
#
# [282473 rows x 11 columns]

# %% [markdown]
# # Feacture scalling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
scaled=sc.fit_transform(df_num)
scaled
# Out:
# array([[-0.48583802, -0.17195033],
#        [-0.69296297,  0.50042902],
#        [ 1.0675991 ,  0.79629966],
#        ...,
#        [-1.31433782, -1.1135186 ],
#        [ 1.37828652, -0.03735588],
#        [-1.0036504 ,  0.06996393]])

# %%
df_num = pd.DataFrame(data=scaled, columns=df_num.columns)
print(df_num)
# Out:
#         Height_(cm)  Weight_(kg)
# 0         -0.485838    -0.171950
# 1         -0.692963     0.500429
# 2          1.067599     0.796300
# 3          0.549787    -0.602415
# 4         -0.485838     1.710593
# ...             ...          ...
# 282468    -0.175151     0.097239
# 282469     1.067599    -0.602415
# 282470    -1.314338    -1.113519
# 282471     1.378287    -0.037356
# 282472    -1.003650     0.069964
#
# [282473 rows x 2 columns]

# %% [markdown]
# # Concatenate Numerical and Categorical Columns

# %%
df_new = pd.concat([df_num,df_object],axis=1)

# %%
df_new
# Out:
#         Height_(cm)  Weight_(kg)  General_Health  Checkup  Exercise  \
# 0         -0.485838    -0.171950               4        4         0
# 1         -0.692963     0.500429               4        4         1
# 2          1.067599     0.796300               3        4         1
# 3          0.549787    -0.602415               1        4         1
# 4         -0.485838     1.710593               2        4         1
# ...             ...          ...             ...      ...       ...
# 282468    -0.175151     0.097239               4        4         1
# 282469     1.067599    -0.602415               1        3         1
# 282470    -1.314338    -1.113519               4        0         1
# 282471     1.378287    -0.037356               4        4         1
# 282472    -1.003650     0.069964               0        4         1
#
#         Heart_Disease  Cancer  Depression  Diabetes  Sex  Age_Category  \
# 0                   1       0           0         1    0            10
# 1                   0       0           0         1    0             8
# 2                   1       0           0         1    1            11
# 3                   1       0           0         0    1             8
# 4                   0       0           0         0    0             9
# ...               ...     ...         ...       ...  ...           ...
# 282468              0       0           0         0    1             1
# 282469              0       0           0         1    1             9
# 282470              0       0           1         1    0             2
# 282471              0       0           0         0    1             9
# 282472              0       0           0         0    0             5
#
#         Smoking_History  Alcohol_Consumption
# 0                     0                    0
# 1                     0                    1
# 2                     0                    0
# 3                     1                    0
# 4                     1                    1
# ...                 ...                  ...
# 282468                0                    1
# 282469                0                    1
# 282470                1                    1
# 282471                0                    1
# 282472                0                    1
#
# [282473 rows x 13 columns]

# %% [markdown]
# # split the data

# %%
y=df_new.iloc[:,5:6]
y
# Out:
#         Heart_Disease
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   0
# ...               ...
# 282468              0
# 282469              0
# 282470              0
# 282471              0
# 282472              0
#
# [282473 rows x 1 columns]

# %%
x=df_new.drop('Heart_Disease',axis=1)
x
# Out:
#         Height_(cm)  Weight_(kg)  General_Health  Checkup  Exercise  Cancer  \
# 0         -0.485838    -0.171950               4        4         0       0
# 1         -0.692963     0.500429               4        4         1       0
# 2          1.067599     0.796300               3        4         1       0
# 3          0.549787    -0.602415               1        4         1       0
# 4         -0.485838     1.710593               2        4         1       0
# ...             ...          ...             ...      ...       ...     ...
# 282468    -0.175151     0.097239               4        4         1       0
# 282469     1.067599    -0.602415               1        3         1       0
# 282470    -1.314338    -1.113519               4        0         1       0
# 282471     1.378287    -0.037356               4        4         1       0
# 282472    -1.003650     0.069964               0        4         1       0
#
#         Depression  Diabetes  Sex  Age_Category  Smoking_History  \
# 0                0         1    0            10                0
# 1                0         1    0             8                0
# 2                0         1    1            11                0
# 3                0         0    1             8                1
# 4                0         0    0             9                1
# ...            ...       ...  ...           ...              ...
# 282468           0         0    1             1                0
# 282469           0         1    1             9                0
# 282470           1         1    0             2                1
# 282471           0         0    1             9                0
# 282472           0         0    0             5                0
#
#         Alcohol_Consumption
# 0                         0
# 1                         1
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 282468                    1
# 282469                    1
# 282470                    1
# 282471                    1
# 282472                    1
#
# [282473 rows x 12 columns]

# %%
Heart_Disease = df['Heart_Disease'].value_counts()
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(5,5))
sns.barplot(x=Heart_Disease.index, y=Heart_Disease.values, palette='bright')
plt.title('Target column "Y"', fontdict={
          'fontname': 'Georgia', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Heart_Disease', fontdict={'fontname': 'Georgia', 'fontsize': 15})
plt.ylabel('value of counts', fontdict={
           'fontname': 'Georgia', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()

# %%
y.value_counts()
# Out:
# Heart_Disease
# 0                259799
# 1                 22674
# Name: count, dtype: int64

# %% [markdown]
# ## Since the Data is imbalanced , need to do sampling (either Oversampling or Undersampling

# %% [markdown]
# ### Oversampling

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(x, y)

# %%
x=x_ros
y=y_ros

# %%
y.value_counts()
# Out:
# Heart_Disease
# 0                259799
# 1                259799
# Name: count, dtype: int64

# %% [markdown]
# # Importing the models and Train them

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
logreg = LogisticRegression()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
xgboost = XGBClassifier()
gbrt = GradientBoostingClassifier()
knn = KNeighborsClassifier()

# %%
def mymodel(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print(classification_report(y_test,y_pred))
    return model

# %% [markdown]
# # Logistic Regression

# %%
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73     77836
#            1       0.72      0.78      0.75     78044
#
#     accuracy                           0.74    155880
#    macro avg       0.74      0.74      0.74    155880
# weighted avg       0.74      0.74      0.74    155880
# LogisticRegression()

# %%
# accuracy score on the train data
y_pred = logreg.predict(x_train)
Train_Accuracy_logreg = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_logreg*100,2),"%")
# Out:
# Accuracy score of the training data :  73.86 %

# %%
# accuracy score on the test data
y_pred_on_test_data = logreg.predict(x_test)
Test_Accuracy_logreg = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_logreg*100,2),"%")
# Out:
# Accuracy score of the test data :  73.74 %

# %% [markdown]
# # GridSearchCV LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Define the parameter grid
param_grid = {
    'C': [0.01,0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga'],               # 'liblinear' for small datasets, 'saga' for larger
    'max_iter': [100, 200, 300],
    'penalty': ['l1', 'l2']                        # 'l1' lasso, 'l2' ridge
}


# Initialize GridSearchCV
grid_search = GridSearchCV(logreg, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the data
grid_search.fit(x_train, y_train)

# Print the best parameters and the best score
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best accuracy found: {grid_search.best_score_}")

# Evaluate the model on the test set
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)
print(f"Test set accuracy: {test_score}")
# Out:
# Best parameters found: {'C': 0.01, 'max_iter': 200, 'penalty': 'l2', 'solver': 'saga'}
# Best accuracy found: 0.7385062133199156
# Test set accuracy: 0.7372658455221965

# %% [markdown]
# # Decision Tree

# %%
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     77836
#            1       0.90      1.00      0.95     78044
#
#     accuracy                           0.94    155880
#    macro avg       0.95      0.94      0.94    155880
# weighted avg       0.95      0.94      0.94    155880
# DecisionTreeClassifier()

# %%
# accuracy score on the train data
y_pred = dt.predict(x_train)
Train_Accuracy_dt = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_dt*100,2),"%")
# Out:
# Accuracy score of the training data :  98.45 %

# %%
# accuracy score on the test data
y_pred_on_test_data = dt.predict(x_test)
Test_Accuracy_dt = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_dt*100,2),"%")
# Out:
# Accuracy score of the test data :  94.34 %

# %% [markdown]
# ### Create a Decision Tree classifier with pruning parameters

# %% [markdown]
# ##### max_depth: Maximum depth of the tree

# %%
dt1 = DecisionTreeClassifier(max_depth=27)

# Train the classifier
dt1.fit(x_train, y_train)

# Predict on the training set
y_train_pred1 = dt1.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt1 = accuracy_score(y_train, y_train_pred1)
print(f'Training Accuracy: {train_accuracy_dt1:.2f}')

# Predict on the test set
y_test_pred1 = dt1.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt1 = accuracy_score(y_test, y_test_pred1)
print(f'Test Accuracy: {test_accuracy_dt1:.2f}')
# Out:
# Training Accuracy: 0.96
# Test Accuracy: 0.93

# %% [markdown]
# ##### min_samples_split: Minimum number of samples required to split an internal node

# %%
dt2 = DecisionTreeClassifier( min_samples_split=9)

# Train the classifier
dt2.fit(x_train, y_train)

# Predict on the training set
y_train_pred2 = dt2.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt2 = accuracy_score(y_train, y_train_pred2)
print(f'Training Accuracy: {train_accuracy_dt2:.2f}')

# Predict on the test set
y_test_pred2 = dt2.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt2 = accuracy_score(y_test, y_test_pred2)
print(f'Test Accuracy: {test_accuracy_dt2:.2f}')
# Out:
# Training Accuracy: 0.97
# Test Accuracy: 0.93

# %% [markdown]
# ##### min_samples_leaf: Minimum number of samples required to be at a leaf node

# %%
dt3 = DecisionTreeClassifier(min_samples_leaf=2)

# Train the classifier
dt3.fit(x_train, y_train)

# Predict on the training set
y_train_pred3 = dt3.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt3 = accuracy_score(y_train, y_train_pred3)
print(f'Training Accuracy: {train_accuracy_dt3:.2f}')

# Predict on the test set
y_test_pred3 = dt3.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt3 = accuracy_score(y_test, y_test_pred3)
print(f'Test Accuracy: {test_accuracy_dt3:.2f}')
# Out:
# Training Accuracy: 0.97
# Test Accuracy: 0.93

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     77836
#            1       0.88      0.99      0.93     78044
#
#     accuracy                           0.93    155880
#    macro avg       0.93      0.93      0.93    155880
# weighted avg       0.93      0.93      0.93    155880

# %%
y_pred_train_data = dt2.predict(x_train)
Train_Accuracy_dt2 = accuracy_score(y_pred_train_data, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_dt2*100,2),"%")
# Out:
# Accuracy score of the training data :  97.42 %

# %%
y_pred_on_test_data = dt2.predict(x_test)
Test_Accuracy_dt2 = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_dt2*100,2),"%")
# Out:
# Accuracy score of the test data :  93.22 %

# %% [markdown]
# # Random forest

# %%
mymodel(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     77836
#            1       0.91      1.00      0.95     78044
#
#     accuracy                           0.95    155880
#    macro avg       0.96      0.95      0.95    155880
# weighted avg       0.96      0.95      0.95    155880
# RandomForestClassifier()

# %%
# accuracy score on the train data
y_pred = rf.predict(x_train)
Train_Accuracy_rf = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_rf*100,2),"%")
# Out:
# Accuracy score of the training data :  98.45 %

# %%
# accuracy score on the test data
y_pred_on_test_data = rf.predict(x_test)
Test_Accuracy_rf = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_rf*100,2),"%")
# Out:
# Accuracy score of the test data :  95.12 %

# %% [markdown]
# # XG Boosting Classifier

# %%
mymodel(xgboost)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77     77836
#            1       0.76      0.83      0.79     78044
#
#     accuracy                           0.78    155880
#    macro avg       0.78      0.78      0.78    155880
# weighted avg       0.78      0.78      0.78    155880
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# accuracy score on the train data
y_pred = xgboost.predict(x_train)
Train_Accuracy_xgboost = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_xgboost*100,2),"%")
# Out:
# Accuracy score of the training data :  78.6 %

# %%
# accuracy score on the test data
y_pred_on_test_data = xgboost.predict(x_test)
Test_Accuracy_xgboost = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_xgboost*100,2),"%")
# Out:
# Accuracy score of the test data :  78.13 %

# %% [markdown]
# # Gradient Boosting Classifier

# %%
mymodel(gbrt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75     77836
#            1       0.74      0.81      0.77     78044
#
#     accuracy                           0.76    155880
#    macro avg       0.77      0.76      0.76    155880
# weighted avg       0.77      0.76      0.76    155880
# GradientBoostingClassifier()

# %%
# accuracy score on the train data
y_pred = gbrt.predict(x_train)
Train_Accuracy_gbrt = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_gbrt*100,2),"%")
# Out:
# Accuracy score of the training data :  76.37 %

# %%
# accuracy score on the test data
y_pred_on_test_data = gbrt.predict(x_test)
Test_Accuracy_gbrt = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_gbrt*100,2),"%")
# Out:
# Accuracy score of the test data :  76.39 %

# %% [markdown]
# # KNN

# %%
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87     77836
#            1       0.82      0.99      0.90     78044
#
#     accuracy                           0.89    155880
#    macro avg       0.90      0.89      0.89    155880
# weighted avg       0.90      0.89      0.89    155880
# KNeighborsClassifier()

# %%
# accuracy score on the train data
y_pred = knn.predict(x_train)
Train_Accuracy_knn = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_knn*100,2),"%")
# Out:
# Accuracy score of the training data :  91.6 %

# %%
# accuracy score on the test data
y_pred_on_test_data = knn.predict(x_test)
Test_Accuracy_knn = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_knn*100,2),"%")
# Out:
# Accuracy score of the test data :  88.68 %

# %% [markdown]
# # GridSearchCV KNN

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Create a KNN classifier object
knn = KNeighborsClassifier()

# Perform grid search using cross-validation
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Print the best hyperparameters found
print("Best hyperparameters:", grid_search.best_params_)

# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
test_accuracy_knn1 = best_model.score(x_test, y_test)
print("Test set accuracy of the best model:", test_accuracy_knn1)
# Out:
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Test set accuracy of the best model: 0.9228701565306646

# %% [markdown]
# # Comparison of models

# %%
ML_Model=['Linear Regression','Decision Tree','Random Forest','Gradient boost','XG boost','k-Nearest Neighbors Regression']

Train_Accuracy=[Train_Accuracy_logreg,Train_Accuracy_dt2,Train_Accuracy_rf,Train_Accuracy_xgboost,Train_Accuracy_gbrt,Train_Accuracy_knn]
Train_ACC = [round(i,3) for i in Train_Accuracy]

Test_Accuracy=[Test_Accuracy_logreg,Test_Accuracy_dt2,Test_Accuracy_rf,Test_Accuracy_xgboost,Test_Accuracy_gbrt,test_accuracy_knn1]
Test_ACC = [round(i,3) for i in Test_Accuracy]

# %%
#creating dataframe
results = pd.DataFrame({ 'ML Model': ML_Model,    
    'Train Accuracy': Train_ACC,
    'Test Accuracy': Test_ACC},index=[1,2,3,4,5,6])

# %%
results
# Out:
#                          ML Model  Train Accuracy  Test Accuracy
# 1               Linear Regression           0.739          0.737
# 2                   Decision Tree           0.974          0.932
# 3                   Random Forest           0.984          0.951
# 4                  Gradient boost           0.786          0.781
# 5                        XG boost           0.764          0.764
# 6  k-Nearest Neighbors Regression           0.916          0.923

# %%
cv_results = pd.DataFrame({
    "Cross Validation Means": [Test_Accuracy_logreg,Test_Accuracy_dt2,Test_Accuracy_rf,Test_Accuracy_xgboost,Test_Accuracy_gbrt,test_accuracy_knn1],
    "ML Models": ['Linear Regression','Decision Tree','Random Forest','Gradient boost','XG boost','k-Nearest Neighbors Regression']
})

# Use sns.barplot with data as the DataFrame
g = sns.barplot(x="Cross Validation Means", y="ML Models", data=cv_results)

# Set labels and title
g.set_xlabel("Mean Accuracy")
g.set_title("Cross Validation Scores")

# Show the plot
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
#  In this project, we build various models like logistic regression, KNeighbors Classifier, decision tree classifier, random forest, Gradient boosting , XG boosting
#
# A Random Forest and decision tree classifier both gives the highest accuracy score of percent among all the ML Models.
#
# So for the Cardiovascular Disease prediction Random Forest Classifier is best model
