# %% [markdown]
# # Cardiovascular Disease Machine Learning Project

# %% [markdown]
# ## INTRODUCTION

# %% [raw]
#                        The Cardiovascular Disease Machine Learning Project aims to study advanced data analysis and machine learning techniques to predict the risk of cardiovascular diseases.
#                        By analyzing various health metrics such as gender, age, health and other lifestyle factors,
# the project seeks to build predictive models that can identify individuals at high risk. This helps in early detection and prevention, leading to better treatment and healthier lives. The project shows how machine learning can improve heart health care.

# %% [markdown]
# ## Description:

# %% [raw]
#                      In this notebook, we are going to predict whether there will be cardiovascular disease or not by using various features like Depression, Diabetes, BMI, Smoking level, Alcohol Consumption,Exercise, health etc
#
#                      The dataset we are going to use is Cardiovascular Disease Machine Learning dataset from Kaggle which contains about 308854 rows and 19 columns features.
#
#                      The dataset contains the labels which we have to predict and the labels are discrete and binary. So the problem we have is a Supervised Classification type.

# %% [markdown]
# ## Motivation:

# %% [raw]
#               Cardiovascular diseases remain a leading cause of mortality worldwide, making early detection crucial for effective management. This project aims to bridge the gap between medical data and actionable insights, enhancing the precision of diagnoses and treatment plans through advanced machine learning techniques.                                                                 By accurately predicting heart disease risk, we can provide timely interventions, reduce healthcare costs, and ultimately save lives through personalized and proactive healthcare.

# %% [markdown]
# ## Column Description

# %% [raw]
# 1. General_Health_Checkup:           Indicates if the individual has undergone a general health checkup.
# 2. Exercise:                         Frequency or type of exercise performed by the individual.
# 3. Heart_Disease:                    Indicates if the individual has been diagnosed with heart disease.
# 4. Skin_Cancer:                      Indicates if the individual has been diagnosed with skin cancer.
# 5. Other_Cancer:                     Indicates if the individual has been diagnosed with cancers other than skin cancer.
# 6. Depression:                       Indicates if the individual has been diagnosed with depression.
# 7. Diabetes:                         Indicates if the individual has been diagnosed with diabetes.
# 8. Arthritis:                        Indicates if the individual has been diagnosed with arthritis.
# 9. Sex:                              Gender of the individual (e.g., male, female).
# 10.Age_Category:                     Age group or category the individual falls into (e.g., 18-24, 25-34, etc.).
# 11.Height_(cm):                      Height of the individual in centimeters.
# 12.Weight_(kg):                      Weight of the individual in kilograms.
# 13.BMI:                              Body Mass Index calculated from height and weight.
# 14.Smoking_History:                  Smoking history of the individual (e.g., never smoked, former smoker, current smoker).
# 15.Alcohol_Consumption:              Frequency or amount of alcohol consumed by the individual.
# 16.Fruit_Consumption:                Frequency of fruit consumption by the individual.
# 17.Green_Vegetables_Consumption:     Frequency of green vegetable consumption by the individual.
# 18.FriedPotato_Consumption:          Frequency of fried potato consumption by the individual.

# %% [markdown]
# # Load libraries

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Dataset

# %%
df =pd.read_csv(r"C:\Users\HP\Documents\ML\CVD pred\df.csv")
df
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 297918      Very Good     Within the past year      Yes            No
# 297919           Fair  Within the past 5 years      Yes            No
# 297920      Very Good      5 or more years ago      Yes            No
# 297921      Very Good     Within the past year      Yes            No
# 297922      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Alcohol_Consumption  \
# count  297923.000000  297923.000000  297923.000000        297923.000000
# mean      169.781407      82.716673      28.618607             5.051245
# std         9.879990      20.718899       6.516161             8.175008
# min        91.000000      24.950000      12.020000             0.000000
# 25%       163.000000      68.040000      24.210000             0.000000
# 50%       170.000000      80.290000      27.440000             1.000000
# 75%       178.000000      93.440000      31.845000             6.000000
# max       190.000000     240.400000      99.330000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      297923.000000                 297923.000000
# mean           29.864458                     15.124619
# std            24.884535                     14.931674
# min             0.000000                      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297923 entries, 0 to 297922
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                297923 non-null  object
#  1   Checkup                       297923 non-null  object
#  2   Exercise                      297923 non-null  object
#  3   Heart_Disease                 297923 non-null  object
#  4   Skin_Cancer                   297923 non-null  object
#  5   Cancer                        297923 non-null  object
#  6   Depression                    297923 non-null  object
#  7   Diabetes                      297923 non-null  object
#  8   Arthritis                     297923 non-null  object
#  9   Sex                           297923 non-null  object
#  10  Age_Category                  297923 non-null  object
#  11  Height_(cm)                   297923 non-null  int64
# ...

# %% [markdown]
# ##### Shape of the data set

# %%
df.shape

#checking size (col,lin) of dataset
print("Number of rows: " + str(df.shape[0]))
print("Number of Columns: " + str(df.shape[1]))
# Out:
# Number of rows: 297923
# Number of Columns: 19

# %% [markdown]
# ##### checking how many unique values there are per column

# %%
df.nunique()
# Out:
# General_Health                     5
# Checkup                            5
# Exercise                           2
# Heart_Disease                      2
# Skin_Cancer                        2
# Cancer                             2
# Depression                         2
# Diabetes                           2
# Arthritis                          2
# Sex                                2
# Age_Category                      13
# Height_(cm)                       77
# Weight_(kg)                      502
# BMI                             3440
# Smoking_History                    2
# Alcohol_Consumption               31
# Fruit_Consumption                 77
# Green_Vegetables_Consumption      75
# FriedPotato_Consumption           67
# dtype: int64

# %%
df.isnull().sum()
# Out:
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Cancer                          0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %%
df.boxplot()
plt.title('Boxplot for All Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### BMI

# %%
df.boxplot(column='BMI')
plt.title('Boxplot for BMI')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['BMI'] < lower_bound) | (df['BMI'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 9226

# %%
df.boxplot(column='BMI')
plt.title('Boxplot for BMI')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### height

# %%
df.boxplot(column='Height_(cm)')
plt.title('Boxplot for Height_(cm)')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['Height_(cm)'].quantile(0.25)
Q3 = df['Height_(cm)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Height_(cm)'] < lower_bound) | (df['Height_(cm)'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 299

# %%
df.boxplot(column='Height_(cm)')
plt.title('Boxplot for Column1')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### weight

# %%
df.boxplot(column='Weight_(kg)')
plt.title('Boxplot for Weight_(kg)')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['Weight_(kg)'].quantile(0.25)
Q3 = df['Weight_(kg)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Weight_(kg)'] < lower_bound) | (df['Weight_(kg)'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 5766

# %%
df.boxplot(column='Weight_(kg)')
plt.title('Boxplot for Weight_(kg)')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ### alchol consumption

# %%
df.boxplot(column='Alcohol_Consumption')
plt.title('Boxplot for Alcohol Consumption')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['Alcohol_Consumption'].quantile(0.25)
Q3 = df['Alcohol_Consumption'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Alcohol_Consumption'] < lower_bound) | (df['Alcohol_Consumption'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Step 2: Drop rows containing outliers from df
df = df.drop(outliers.index)
# Out:
# Number of outliers: 33651

# %%
df.boxplot(column='Alcohol_Consumption')
plt.title('Boxplot for Alcohol Consumption')
plt.ylabel('Values')
plt.show()

# %%
df.boxplot()
plt.title('Boxplot for All Columns')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.xticks(rotation = 90)
plt.show()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0           Very Good     Within the past year       No           Yes
# 1           Very Good     Within the past year      Yes            No
# 2                Poor     Within the past year      Yes           Yes
# 3                Fair     Within the past year      Yes           Yes
# 4                Good     Within the past year      Yes            No
# ...               ...                      ...      ...           ...
# 248976      Very Good     Within the past year      Yes            No
# 248977           Fair  Within the past 5 years      Yes            No
# 248978      Very Good      5 or more years ago      Yes            No
# 248979      Very Good     Within the past year      Yes            No
# 248980      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# ...

# %% [markdown]
# ##### Checking null values

# %%
df.isnull().sum()
# Out:
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Cancer                          0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# ##### Heart Disease by Age Distribution

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Age_Category', hue='Heart_Disease', data=df)
plt.title('Age Distribution and Heart Disease')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### Heart Disease by gender

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='Sex', hue='Heart_Disease', data=df)
plt.title('Heart Disease in gender')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Heart Disease', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ##### General Health

# %%
plt.figure(figsize=(5,5))
occupation_counts = df['General_Health'].value_counts()
plt.pie(occupation_counts, labels=occupation_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('General_Health')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### Health Checkup Frequency Distribution

# %%
checkup_counts = df['Checkup'].value_counts()

# Pie chart
plt.figure(figsize=(8, 6))
plt.pie(checkup_counts, labels=checkup_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Checkup Frequency Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### Exercise and Heart Disease

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x='Exercise', hue='Heart_Disease', data=df)
plt.title('Exercise and Heart Disease')
plt.xlabel('Exercise History')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### Distribution of Depression by Gender

# %%
depression_by_gender = df.groupby(['Sex', 'Depression']).size()

# Plot stacked bar chart
depression_by_gender.plot(kind='bar', stacked=True, figsize=(6, 6))
plt.title('Distribution of Depression by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Depression')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### Alcohol Consumption by gender

# %%
plt.figure(figsize=(5,4))
sns.barplot(x='Sex', y='Alcohol_Consumption', data=df, palette='muted', ci=None)
plt.title('Alcohol Consumption by Gender')
plt.xlabel('Age Category')
plt.ylabel('Mean Alcohol Consumption')
plt.xticks(rotation=10)
plt.show()

# %% [markdown]
# ##### Alcohol Consumption by Age Category

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Age_Category', y='Alcohol_Consumption', data=df, ci=None)
plt.title('Alcohol Consumption by Age Category')
plt.xlabel('Age Category')
plt.ylabel('FriedPotato Consumption')
plt.show()

# %% [markdown]
# ##### Smoking History by Gender

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Sex', hue='Smoking_History', data=df)
plt.title('Smoking History by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Smoking History')
plt.show()

# %% [markdown]
# #### Smoking Consumption by Age Categories

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Age_Category', hue='Smoking_History', data=df, palette='Set2')
plt.title('Smoking History by Age Categories')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Smoking History')
plt.show()

# %% [markdown]
# ##### FriedPotato Consumption by Gender

# %%
plt.figure(figsize=(5,4))
sns.barplot(x='Sex', y='FriedPotato_Consumption', data=df, ci=None)
plt.title('FriedPotato Consumption in Gender')
plt.xlabel('Sex')
plt.ylabel('FriedPotato Consumption')
plt.show()

# %% [markdown]
# # Drop unnecessary columns

# %%
df.drop('Green_Vegetables_Consumption', axis=1, inplace=True)
df.drop('FriedPotato_Consumption', axis=1, inplace=True)
df.drop('Fruit_Consumption', axis=1, inplace=True)
df.drop('Skin_Cancer', axis=1, inplace=True)
df.drop('BMI', axis=1, inplace=True)
df.drop('Arthritis', axis=1, inplace=True)

# %% [markdown]
# # Separting Numeric and category Data

# %%
df_num=df.select_dtypes(['int','float'])
df_num
# Out:
#         Height_(cm)  Weight_(kg)  Alcohol_Consumption
# 0               165        77.11                    0
# 1               163        88.45                    4
# 2               180        93.44                    0
# 3               175        69.85                    0
# 4               165       108.86                    3
# ...             ...          ...                  ...
# 248976          168        81.65                    4
# 248977          180        69.85                    8
# 248978          157        61.23                    4
# 248979          183        79.38                    3
# 248980          160        81.19                    1
#
# [248981 rows x 3 columns]

# %%
df_object=df.select_dtypes(['object'])
df_object
# Out:
#        General_Health                  Checkup Exercise Heart_Disease Cancer  \
# 0           Very Good     Within the past year       No           Yes     No
# 1           Very Good     Within the past year      Yes            No     No
# 2                Poor     Within the past year      Yes           Yes     No
# 3                Fair     Within the past year      Yes           Yes     No
# 4                Good     Within the past year      Yes            No     No
# ...               ...                      ...      ...           ...    ...
# 248976      Very Good     Within the past year      Yes            No     No
# 248977           Fair  Within the past 5 years      Yes            No     No
# 248978      Very Good      5 or more years ago      Yes            No     No
# 248979      Very Good     Within the past year      Yes            No     No
# 248980      Excellent     Within the past year      Yes            No     No
#
# ...

# %% [markdown]
# # Using Label Encoder for converting category data into numeric

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df_object:
    df_object[i]=le.fit_transform(df_object[i]) 
#convert the cat to label encoder
df_object
# Out:
#         General_Health  Checkup  Exercise  Heart_Disease  Cancer  Depression  \
# 0                    4        4         0              1       0           0
# 1                    4        4         1              0       0           0
# 2                    3        4         1              1       0           0
# 3                    1        4         1              1       0           0
# 4                    2        4         1              0       0           0
# ...                ...      ...       ...            ...     ...         ...
# 248976               4        4         1              0       0           0
# 248977               1        3         1              0       0           0
# 248978               4        0         1              0       0           1
# 248979               4        4         1              0       0           0
# 248980               0        4         1              0       0           0
#
# ...

# %% [markdown]
# # Feacture scalling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
scaled=sc.fit_transform(df_num)
scaled
# Out:
# array([[-0.44972985, -0.17707603, -0.66136643],
#        [-0.65679649,  0.49133811,  0.4006665 ],
#        [ 1.10326999,  0.78546391, -0.66136643],
#        ...,
#        [-1.27799642, -1.11309159,  0.4006665 ],
#        [ 1.41386995, -0.04327531,  0.13515827],
#        [-0.96739646,  0.0634116 , -0.3958582 ]])

# %%
df_num = pd.DataFrame(data=scaled, columns=df_num.columns)
print(df_num)
# Out:
#         Height_(cm)  Weight_(kg)  Alcohol_Consumption
# 0         -0.449730    -0.177076            -0.661366
# 1         -0.656796     0.491338             0.400667
# 2          1.103270     0.785464            -0.661366
# 3          0.585603    -0.605003            -0.661366
# 4         -0.449730     1.694366             0.135158
# ...             ...          ...                  ...
# 248976    -0.139130     0.090525             0.400667
# 248977     1.103270    -0.605003             1.462699
# 248978    -1.277996    -1.113092             0.400667
# 248979     1.413870    -0.043275             0.135158
# 248980    -0.967396     0.063412            -0.395858
#
# [248981 rows x 3 columns]

# %% [markdown]
# # Concatenate Numerical and Categorical Columns

# %%
df_new = pd.concat([df_num,df_object],axis=1)

# %%
df_new
# Out:
#         Height_(cm)  Weight_(kg)  Alcohol_Consumption  General_Health  \
# 0         -0.449730    -0.177076            -0.661366               4
# 1         -0.656796     0.491338             0.400667               4
# 2          1.103270     0.785464            -0.661366               3
# 3          0.585603    -0.605003            -0.661366               1
# 4         -0.449730     1.694366             0.135158               2
# ...             ...          ...                  ...             ...
# 248976    -0.139130     0.090525             0.400667               4
# 248977     1.103270    -0.605003             1.462699               1
# 248978    -1.277996    -1.113092             0.400667               4
# 248979     1.413870    -0.043275             0.135158               4
# 248980    -0.967396     0.063412            -0.395858               0
#
#         Checkup  Exercise  Heart_Disease  Cancer  Depression  Diabetes  Sex  \
# ...

# %% [markdown]
# # split the data

# %%
y=df_new.iloc[:,6:7]
y
# Out:
#         Heart_Disease
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   0
# ...               ...
# 248976              0
# 248977              0
# 248978              0
# 248979              0
# 248980              0
#
# [248981 rows x 1 columns]

# %%
x=df_new.drop('Heart_Disease',axis=1)
x
# Out:
#         Height_(cm)  Weight_(kg)  Alcohol_Consumption  General_Health  \
# 0         -0.449730    -0.177076            -0.661366               4
# 1         -0.656796     0.491338             0.400667               4
# 2          1.103270     0.785464            -0.661366               3
# 3          0.585603    -0.605003            -0.661366               1
# 4         -0.449730     1.694366             0.135158               2
# ...             ...          ...                  ...             ...
# 248976    -0.139130     0.090525             0.400667               4
# 248977     1.103270    -0.605003             1.462699               1
# 248978    -1.277996    -1.113092             0.400667               4
# 248979     1.413870    -0.043275             0.135158               4
# 248980    -0.967396     0.063412            -0.395858               0
#
#         Checkup  Exercise  Cancer  Depression  Diabetes  Sex  Age_Category  \
# ...

# %%
Heart_Disease = df['Heart_Disease'].value_counts()
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(5,5))
sns.barplot(x=Heart_Disease.index, y=Heart_Disease.values, palette='bright')
plt.title('Target column "Y"', fontdict={
          'fontname': 'Georgia', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Heart_Disease', fontdict={'fontname': 'Georgia', 'fontsize': 15})
plt.ylabel('value of counts', fontdict={
           'fontname': 'Georgia', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()

# %%
y.value_counts()
# Out:
# Heart_Disease
# 0                228692
# 1                 20289
# Name: count, dtype: int64

# %% [markdown]
# ## Since the Data is imbalanced , need to do sampling (either Oversampling or Undersampling

# %% [markdown]
# ### Oversampling

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(x, y)

# %%
x=x_ros
y=y_ros

# %%
y.value_counts()
# Out:
# Heart_Disease
# 0                228692
# 1                228692
# Name: count, dtype: int64

# %% [markdown]
# # Importing the models and Train them

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
logreg = LogisticRegression()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
xgboost = XGBClassifier()
gbrt = GradientBoostingClassifier()
knn = KNeighborsClassifier()

# %%
def mymodel(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print(classification_report(y_test,y_pred))
    return model

# %% [markdown]
# # Logistic Regression

# %%
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73     68633
#            1       0.72      0.78      0.75     68583
#
#     accuracy                           0.74    137216
#    macro avg       0.74      0.74      0.74    137216
# weighted avg       0.74      0.74      0.74    137216
# LogisticRegression()

# %%
# accuracy score on the train data
y_pred = logreg.predict(x_train)
Train_Accuracy_logreg = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_logreg*100,2),"%")
# Out:
# Accuracy score of the training data :  74.18 %

# %%
# accuracy score on the test data
y_pred_on_test_data = logreg.predict(x_test)
Test_Accuracy_logreg = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_logreg*100,2),"%")
# Out:
# Accuracy score of the test data :  74.21 %

# %% [markdown]
# # GridSearchCV LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Define the parameter grid
param_grid = {
    'C': [0.01,0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga'],               # 'liblinear' for small datasets, 'saga' for larger
    'max_iter': [100, 200, 300],
    'penalty': ['l1', 'l2']                        # 'l1' lasso, 'l2' ridge
}


# Initialize GridSearchCV
grid_search = GridSearchCV(logreg, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the data
grid_search.fit(x_train, y_train)

# Print the best parameters and the best score
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best accuracy found: {grid_search.best_score_}")

# Evaluate the model on the test set
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)
print(f"Test set accuracy: {test_score}")
# Out:
# Best parameters found: {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Best accuracy found: 0.7419667225115253
# Test set accuracy: 0.7422895289179104

# %% [markdown]
# # Decision Tree

# %%
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     68633
#            1       0.91      1.00      0.95     68583
#
#     accuracy                           0.95    137216
#    macro avg       0.95      0.95      0.95    137216
# weighted avg       0.95      0.95      0.95    137216
# DecisionTreeClassifier()

# %%
# accuracy score on the train data
y_pred = dt.predict(x_train)
Train_Accuracy_dt = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_dt*100,2),"%")
# Out:
# Accuracy score of the training data :  99.18 %

# %%
# accuracy score on the test data
y_pred_on_test_data = dt.predict(x_test)
Test_Accuracy_dt = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_dt*100,2),"%")
# Out:
# Accuracy score of the test data :  94.8 %

# %% [markdown]
# ### Create a Decision Tree classifier with pruning parameters

# %% [markdown]
# ##### max_depth: Maximum depth of the tree

# %%
dt1 = DecisionTreeClassifier(max_depth=22)

# Train the classifier
dt1.fit(x_train, y_train)

# Predict on the training set
y_train_pred1 = dt1.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt1 = accuracy_score(y_train, y_train_pred1)
print(f'Training Accuracy: {train_accuracy_dt1:.2f}')

# Predict on the test set
y_test_pred1 = dt1.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt1 = accuracy_score(y_test, y_test_pred1)
print(f'Test Accuracy: {test_accuracy_dt1:.2f}')
# Out:
# Training Accuracy: 0.93
# Test Accuracy: 0.90

# %% [markdown]
# ##### min_samples_split: Minimum number of samples required to split an internal node

# %%
dt2 = DecisionTreeClassifier( min_samples_split=15)

# Train the classifier
dt2.fit(x_train, y_train)

# Predict on the training set
y_train_pred2 = dt2.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt2 = accuracy_score(y_train, y_train_pred2)
print(f'Training Accuracy: {train_accuracy_dt2:.2f}')

# Predict on the test set
y_test_pred2 = dt2.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt2 = accuracy_score(y_test, y_test_pred2)
print(f'Test Accuracy: {test_accuracy_dt2:.2f}')
# Out:
# Training Accuracy: 0.95
# Test Accuracy: 0.91

# %% [markdown]
# ##### min_samples_leaf: Minimum number of samples required to be at a leaf node

# %%
dt3 = DecisionTreeClassifier(min_samples_leaf=4)

# Train the classifier
dt3.fit(x_train, y_train)

# Predict on the training set
y_train_pred3 = dt3.predict(x_train)

# Evaluate the classifier on the training set
train_accuracy_dt3 = accuracy_score(y_train, y_train_pred3)
print(f'Training Accuracy: {train_accuracy_dt3:.2f}')

# Predict on the test set
y_test_pred3 = dt3.predict(x_test)

# Evaluate the classifier on the test set
test_accuracy_dt3 = accuracy_score(y_test, y_test_pred3)
print(f'Test Accuracy: {test_accuracy_dt3:.2f}')
# Out:
# Training Accuracy: 0.94
# Test Accuracy: 0.90

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.90     68633
#            1       0.87      0.96      0.91     68583
#
#     accuracy                           0.91    137216
#    macro avg       0.91      0.91      0.91    137216
# weighted avg       0.91      0.91      0.91    137216

# %%
y_pred_train_data = dt2.predict(x_train)
Train_Accuracy_dt2 = accuracy_score(y_pred_train_data, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_dt2*100,2),"%")
# Out:
# Accuracy score of the training data :  95.27 %

# %%
y_pred_on_test_data = dt2.predict(x_test)
Test_Accuracy_dt2 = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_dt2*100,2),"%")
# Out:
# Accuracy score of the test data :  90.98 %

# %% [markdown]
# # Random forest

# %%
mymodel(rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     68633
#            1       0.93      1.00      0.96     68583
#
#     accuracy                           0.96    137216
#    macro avg       0.96      0.96      0.96    137216
# weighted avg       0.96      0.96      0.96    137216
# RandomForestClassifier()

# %%
# accuracy score on the train data
y_pred = rf.predict(x_train)
Train_Accuracy_rf = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_rf*100,2),"%")
# Out:
# Accuracy score of the training data :  99.18 %

# %%
# accuracy score on the test data
y_pred_on_test_data = rf.predict(x_test)
Test_Accuracy_rf = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_rf*100,2),"%")
# Out:
# Accuracy score of the test data :  95.98 %

# %% [markdown]
# # XG Boosting Classifier

# %%
mymodel(xgboost)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.77     68633
#            1       0.76      0.85      0.80     68583
#
#     accuracy                           0.79    137216
#    macro avg       0.79      0.79      0.79    137216
# weighted avg       0.79      0.79      0.79    137216
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
# accuracy score on the train data
y_pred = xgboost.predict(x_train)
Train_Accuracy_xgboost = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_xgboost*100,2),"%")
# Out:
# Accuracy score of the training data :  79.43 %

# %%
# accuracy score on the test data
y_pred_on_test_data = xgboost.predict(x_test)
Test_Accuracy_xgboost = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_xgboost*100,2),"%")
# Out:
# Accuracy score of the test data :  78.78 %

# %% [markdown]
# # Gradient Boosting Classifier

# %%
mymodel(gbrt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75     68633
#            1       0.74      0.82      0.78     68583
#
#     accuracy                           0.77    137216
#    macro avg       0.77      0.77      0.77    137216
# weighted avg       0.77      0.77      0.77    137216
# GradientBoostingClassifier()

# %%
# accuracy score on the train data
y_pred = gbrt.predict(x_train)
Train_Accuracy_gbrt = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_gbrt*100,2),"%")
# Out:
# Accuracy score of the training data :  76.67 %

# %%
# accuracy score on the test data
y_pred_on_test_data = gbrt.predict(x_test)
Test_Accuracy_gbrt = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_gbrt*100,2),"%")
# Out:
# Accuracy score of the test data :  76.59 %

# %% [markdown]
# # KNN

# %%
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.88     68633
#            1       0.82      0.99      0.90     68583
#
#     accuracy                           0.89    137216
#    macro avg       0.91      0.89      0.89    137216
# weighted avg       0.91      0.89      0.89    137216
# KNeighborsClassifier()

# %%
# accuracy score on the train data
y_pred = knn.predict(x_train)
Train_Accuracy_knn = accuracy_score(y_pred, y_train)
print('Accuracy score of the training data : ', round(Train_Accuracy_knn*100,2),"%")
# Out:
# Accuracy score of the training data :  91.8 %

# %%
# accuracy score on the test data
y_pred_on_test_data = knn.predict(x_test)
Test_Accuracy_knn = accuracy_score(y_pred_on_test_data, y_test)
print('Accuracy score of the test data : ', round(Test_Accuracy_knn*100,2),"%")
# Out:
# Accuracy score of the test data :  88.82 %

# %% [markdown]
# # GridSearchCV KNN

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Create a KNN classifier object
knn = KNeighborsClassifier()

# Perform grid search using cross-validation
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Print the best hyperparameters found
print("Best hyperparameters:", grid_search.best_params_)

# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
test_accuracy_knn1 = best_model.score(x_test, y_test)
print("Test set accuracy of the best model:", test_accuracy_knn1)
# Out:
# Best hyperparameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Test set accuracy of the best model: 0.92529296875

# %% [markdown]
# # Comparison of models

# %%
ML_Model=['Linear Regression','Decision Tree','Random Forest','Gradient boost','XG boost','k-Nearest Neighbors Regression']

Train_Accuracy=[Train_Accuracy_logreg,Train_Accuracy_dt2,Train_Accuracy_rf,Train_Accuracy_xgboost,Train_Accuracy_gbrt,Train_Accuracy_knn]
Train_ACC = [round(i,3) for i in Train_Accuracy]

Test_Accuracy=[Test_Accuracy_logreg,Test_Accuracy_dt2,Test_Accuracy_rf,Test_Accuracy_xgboost,Test_Accuracy_gbrt,test_accuracy_knn1]
Test_ACC = [round(i,3) for i in Test_Accuracy]

# %%
#creating dataframe
results = pd.DataFrame({ 'ML Model': ML_Model,    
    'Train Accuracy': Train_ACC,
    'Test Accuracy': Test_ACC},index=[1,2,3,4,5,6])

# %%
results
# Out:
#                          ML Model  Train Accuracy  Test Accuracy
# 1               Linear Regression           0.742          0.742
# 2                   Decision Tree           0.953          0.910
# 3                   Random Forest           0.992          0.960
# 4                  Gradient boost           0.794          0.788
# 5                        XG boost           0.767          0.766
# 6  k-Nearest Neighbors Regression           0.918          0.925

# %%
cv_results = pd.DataFrame({
    "Cross Validation Means": [Test_Accuracy_logreg,Test_Accuracy_dt2,Test_Accuracy_rf,Test_Accuracy_xgboost,Test_Accuracy_gbrt,test_accuracy_knn1],
    "ML Models": ['Linear Regression','Decision Tree','Random Forest','Gradient boost','XG boost','k-Nearest Neighbors Regression']
})

# Use sns.barplot with data as the DataFrame
g = sns.barplot(x="Cross Validation Means", y="ML Models", data=cv_results)

# Set labels and title
g.set_xlabel("Mean Accuracy")
g.set_title("Cross Validation Scores")

# Show the plot
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
#  In this project, we build various models like logistic regression, KNeighbors Classifier, decision tree classifier, random forest, Gradient boosting , XG boosting
#
# A Random Forest and decision tree classifier both gives the highest accuracy score of percent among all the ML Models.
#
# So for the Cardiovascular Disease prediction Random Forest Classifier is best model
