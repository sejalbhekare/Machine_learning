# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\Factors_ affecting_ university_student_grades_dataset.csv")

# %%
df
# Out:
#         Age Gender Parental_Education Family_Income Previous_Grades  \
# 0      22.0      F            College         50000               A
# 1      21.0      M                NaN         60000               A
# 2      19.0      M            College         75000               C
# 3      21.0      M            College         60000               A
# 4      19.0    NaN                NaN         40000             NaN
# ...     ...    ...                ...           ...             ...
# 10059  20.0    NaN       Some College         75000               A
# 10060  19.0      M            College           NaN               B
# 10061  20.0      M                NaN         30000               B
# 10062  21.0      F            College         50000               B
# 10063  18.0      F       Some College         30000               A
#
#        Attendance Class_Participation  Study_Hours       stream School_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          9099 non-null   float64
#  1   Gender                       9085 non-null   object
#  2   Parental_Education           9102 non-null   object
#  3   Family_Income                9097 non-null   object
#  4   Previous_Grades              9120 non-null   object
#  5   Attendance                   9060 non-null   float64
#  6   Class_Participation          9098 non-null   object
#  7   Study_Hours                  9073 non-null   float64
#  8   stream                       9136 non-null   object
#  9   School_Type                  9115 non-null   object
#  10  Financial_Status             9129 non-null   object
#  11  Parental_Involvement         9118 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age   Attendance  Study_Hours   Class_Size  Sleep_Patterns  \
# count  9099.000000  9060.000000  9073.000000  9114.000000     9048.000000
# mean     19.996703    84.908499    12.467761    60.238754        6.538904
# std       1.406885     8.985221     4.613845    23.337209        1.720632
# min      18.000000    70.000000     5.000000    20.000000        4.000000
# 25%      19.000000    77.000000     9.000000    40.000000        5.000000
# 50%      20.000000    85.000000    12.000000    61.000000        7.000000
# 75%      21.000000    93.000000    16.000000    80.000000        8.000000
# max      22.000000   100.000000    20.000000   100.000000        9.000000
#
#        Screen_Time  Time_Wasted_on_Social_Media
# count  9120.000000                  9137.000000
# mean      6.031469                     3.489329
# std       2.597880                     1.704057
# min       2.000000                     1.000000
# 25%       4.000000                     2.000000
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Parental_Education', 'Family_Income',
#        'Previous_Grades', 'Attendance', 'Class_Participation', 'Study_Hours',
#        'stream', 'School_Type', 'Financial_Status', 'Parental_Involvement',
#        'Educational_Resources', 'Motivation', 'Self_Esteem', 'Stress_Levels',
#        'School_Environment', 'Professor_Quality', 'Class_Size',
#        'Extracurricular_Activities', 'Sleep_Patterns', 'Nutrition',
#        'Physical_Activity', 'Screen_Time', 'Educational_Tech_Use',
#        'Peer_Group', 'Bullying', 'Study_Space', 'Learning_Style', 'Tutoring',
#        'Mentoring', 'Lack_of_Interest', 'Time_Wasted_on_Social_Media',
#        'Sports_Participation', 'Grades'],
#       dtype='object')

# %%
unique_values = df['Family_Income'].unique()

print("Unique values in 'Family_Income' column:")
print(unique_values)
# Out:
# Unique values in 'Family_Income' column:
# ['50000' '60000' '75000' '40000' nan '30000' 'Unknown']

# %%
df['Family_Income'] = df['Family_Income'].replace('Unknown', np.nan)

# %%
unique_values = df['Family_Income'].unique()
unique_values
# Out:
# array(['50000', '60000', '75000', '40000', nan, '30000'], dtype=object)

# %%
df['Family_Income'] = df['Family_Income'].astype(float)

# %%
df.isnull().sum()
# Out:
# Age                             965
# Gender                          979
# Parental_Education              962
# Family_Income                   968
# Previous_Grades                 944
# Attendance                     1004
# Class_Participation             966
# Study_Hours                     991
# stream                          928
# School_Type                     949
# Financial_Status                935
# Parental_Involvement            946
# Educational_Resources           935
# Motivation                      970
# Self_Esteem                     912
# Stress_Levels                   919
# School_Environment              958
# Professor_Quality               950
# Class_Size                      950
# Extracurricular_Activities      905
# Sleep_Patterns                 1016
# Nutrition                       977
# Physical_Activity               974
# Screen_Time                     944
# Educational_Tech_Use            993
# Peer_Group                      919
# ...

# %%
df_mean=df['Age'].mean()
df['Age']=df['Age'].fillna(df_mean)

df_mean=df['Family_Income'].mean()
df['Family_Income']=df['Family_Income'].fillna(df_mean)

df_mean=df['Attendance'].mean()
df['Attendance']=df['Attendance'].fillna(df_mean)

df_mean=df['Study_Hours'].mean()
df['Study_Hours']=df['Study_Hours'].fillna(df_mean)

df_mean=df['Class_Size'].mean()
df['Class_Size']=df['Class_Size'].fillna(df_mean)

df_mean=df['Sleep_Patterns'].mean()
df['Sleep_Patterns']=df['Sleep_Patterns'].fillna(df_mean)

df_mean=df['Screen_Time'].mean()
df['Screen_Time']=df['Screen_Time'].fillna(df_mean)

df_mean=df['Time_Wasted_on_Social_Media'].mean()
df['Time_Wasted_on_Social_Media']=df['Time_Wasted_on_Social_Media'].fillna(df_mean)

# %%
mode_value= df["Gender"].mode()[0]
df["Gender"].fillna(mode_value, inplace= True)

mode_value= df["Parental_Education"].mode()[0]
df["Parental_Education"].fillna(mode_value, inplace= True)

mode_value= df["Previous_Grades"].mode()[0]
df["Previous_Grades"].fillna(mode_value, inplace= True)

mode_value= df["Class_Participation"].mode()[0]
df["Class_Participation"].fillna(mode_value, inplace= True)

mode_value= df["stream"].mode()[0]
df["stream"].fillna(mode_value, inplace= True)

mode_value= df["School_Type"].mode()[0]
df["School_Type"].fillna(mode_value, inplace= True)

mode_value= df["Financial_Status"].mode()[0]
df["Financial_Status"].fillna(mode_value, inplace= True)

mode_value= df["Parental_Involvement"].mode()[0]
df["Parental_Involvement"].fillna(mode_value, inplace= True)

mode_value= df["Educational_Resources"].mode()[0]
df["Educational_Resources"].fillna(mode_value, inplace= True)

mode_value= df["Motivation"].mode()[0]
df["Motivation"].fillna(mode_value, inplace= True)

mode_value= df["Self_Esteem"].mode()[0]
df["Self_Esteem"].fillna(mode_value, inplace= True)

mode_value= df["Stress_Levels"].mode()[0]
df["Stress_Levels"].fillna(mode_value, inplace= True)

mode_value= df["School_Environment"].mode()[0]
df["School_Environment"].fillna(mode_value, inplace= True)

mode_value= df["Professor_Quality"].mode()[0]
df["Professor_Quality"].fillna(mode_value, inplace= True)

mode_value= df["Extracurricular_Activities"].mode()[0]
df["Extracurricular_Activities"].fillna(mode_value, inplace= True)

mode_value= df["Nutrition"].mode()[0]
df["Nutrition"].fillna(mode_value, inplace= True)

mode_value= df["Physical_Activity"].mode()[0]
df["Physical_Activity"].fillna(mode_value, inplace= True)

mode_value= df["Sports_Participation"].mode()[0]
df["Sports_Participation"].fillna(mode_value, inplace= True)

mode_value= df["Educational_Tech_Use"].mode()[0]
df["Educational_Tech_Use"].fillna(mode_value, inplace= True)

mode_value= df["Peer_Group"].mode()[0]
df["Peer_Group"].fillna(mode_value, inplace= True)

mode_value= df["Bullying"].mode()[0]
df["Bullying"].fillna(mode_value, inplace= True)

mode_value= df["Study_Space"].mode()[0]
df["Study_Space"].fillna(mode_value, inplace= True)

mode_value= df["Learning_Style"].mode()[0]
df["Learning_Style"].fillna(mode_value, inplace= True)

mode_value= df["Tutoring"].mode()[0]
df["Tutoring"].fillna(mode_value, inplace= True)

mode_value= df["Mentoring"].mode()[0]
df["Mentoring"].fillna(mode_value, inplace= True)

mode_value= df["Lack_of_Interest"].mode()[0]
df["Lack_of_Interest"].fillna(mode_value, inplace= True)

mode_value= df["Grades"].mode()[0]
df["Grades"].fillna(mode_value, inplace= True)

# %%
df.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# Parental_Education             0
# Family_Income                  0
# Previous_Grades                0
# Attendance                     0
# Class_Participation            0
# Study_Hours                    0
# stream                         0
# School_Type                    0
# Financial_Status               0
# Parental_Involvement           0
# Educational_Resources          0
# Motivation                     0
# Self_Esteem                    0
# Stress_Levels                  0
# School_Environment             0
# Professor_Quality              0
# Class_Size                     0
# Extracurricular_Activities     0
# Sleep_Patterns                 0
# Nutrition                      0
# Physical_Activity              0
# Screen_Time                    0
# Educational_Tech_Use           0
# Peer_Group                     0
# Bullying                       0
# Study_Space                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          10064 non-null  float64
#  1   Gender                       10064 non-null  object
#  2   Parental_Education           10064 non-null  object
#  3   Family_Income                10064 non-null  float64
#  4   Previous_Grades              10064 non-null  object
#  5   Attendance                   10064 non-null  float64
#  6   Class_Participation          10064 non-null  object
#  7   Study_Hours                  10064 non-null  float64
#  8   stream                       10064 non-null  object
#  9   School_Type                  10064 non-null  object
#  10  Financial_Status             10064 non-null  object
#  11  Parental_Involvement         10064 non-null  object
# ...
